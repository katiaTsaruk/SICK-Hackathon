# %%
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import albumentations as A
import cv2

# %%
with open('./dtag_rectangle_20241126/dtag_export/annotations/instances_test.json', 'r') as file:
    test_data = json.load(file)

# %%
test_data_path = './dtag_rectangle_20241126/dtag_export/test/'

# %%
print(test_data["images"])
# Out:
# [{'license': 'NA', 'file_name': 'e6a13ff6-14e3-4ec3-a746-b4d48fcf8ba2.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-10-08 13:32:39.035000+00:00', 'id': 251}, {'license': 'NA', 'file_name': 'e86aba0f-87fc-4ad5-a704-f1ca17daca0d.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-08-28 12:12:26.582000+00:00', 'id': 252}, {'license': 'NA', 'file_name': 'ea0681b1-06c4-466e-becb-ca95fa6ee1dd.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-08-28 12:12:26.491000+00:00', 'id': 253}, {'license': 'NA', 'file_name': 'eab8b176-dc24-417f-8edc-f7bce36e34ad.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-08-26 13:38:51.470000+00:00', 'id': 254}, {'license': 'NA', 'file_name': 'eb149362-5611-4366-8bfa-5266c287e51c.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-08-26 13:38:51.420000+00:00', 'id': 255}, {'license': 'NA', 'file_name': 'eb2ebf27-d771-4519-a621-71bf6e7f6461.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-08-26 13:38:51.5280
# ...

# %%
print(test_data["images"][0])
# Out:
# {'license': 'NA', 'file_name': 'e6a13ff6-14e3-4ec3-a746-b4d48fcf8ba2.jpeg', 'height': 576, 'width': 768, 'date_captured': '2024-10-08 13:32:39.035000+00:00', 'id': 251}

# %%
print(test_data["images"][0]["file_name"])
# Out:
# e6a13ff6-14e3-4ec3-a746-b4d48fcf8ba2.jpeg

# %%
img = mpimg.imread('C:/Users/ricar/Documents/Programming/hackathon_SICK/dtag_rectangle_20241126/dtag_export/test/e6a13ff6-14e3-4ec3-a746-b4d48fcf8ba2.jpeg')

# %%
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
img = Image.open('C:/Users/ricar/Documents/Programming/hackathon_SICK/dtag_rectangle_20241126/dtag_export/test/e6a13ff6-14e3-4ec3-a746-b4d48fcf8ba2.jpeg')
img.show()

# %%
transform = A.Compose([
    A.RandomBrightnessContrast(p=0.7),
    A.Blur(blur_limit=(3,7), p=1.0),
    A.ISONoise(color_shift=(0.01, 0.05), intensity=(0.1, 0.5), p=0.5)
])

# %%
#print(dir(A))

# %%
image = cv2.imread('C:/Users/ricar/Documents/Programming/hackathon_SICK/dtag_rectangle_20241126/dtag_export/test/e6a13ff6-14e3-4ec3-a746-b4d48fcf8ba2.jpeg')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
transformed = transform(image=image)

# %%
type(transformed)
# Out:
# dict

# %%
transformed
# Out:
# {'image': array([[[254, 254, 254],
#          [249, 249, 249],
#          [237, 237, 237],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[253, 253, 253],
#          [248, 248, 248],
#          [235, 235, 235],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[251, 251, 251],
#          [245, 245, 245],
#          [231, 231, 231],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[125, 125, 125],
#          [124, 124, 124],
#          [118, 118, 118],
#          ...,
#          [229, 229, 229],
#          [228, 228, 228],
#          [228, 228, 228]],
#
#         [[125, 125, 125],
#          [123, 123, 123],
#          [118, 118, 118],
#          ...,
#          [228, 228, 228],
#          [227, 227, 227],
#          [227, 227, 227]],
#
#         [[125, 125, 125],
# ...

# %%
transformed_image = transformed["image"]

# %%
type(transformed_image)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('C:/Users/ricar/Documents/Programming/hackathon_SICK/dtag_rectangle_20241126/dtag_export/test/transformed_img.jpeg', transformed_image)
# Out:
# True

# %%
plt.imshow(transformed_image)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(575.5), np.float64(-0.5))
